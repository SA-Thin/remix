# %%
import random as r
from textblob import TextBlob

with open('words.txt', 'r') as file:
    text = file.read()
    
blob = TextBlob(text)

adjectives = []
nouns = []
conjunction = []
preposition = []

for word, pos in blob.tags:
    if (pos == 'JJ'):
        adjectives.append(word)
    if (pos == 'NN'):
        nouns.append(word)
    if (pos == 'CC'):
        conjunction.append(word)
    if (pos == 'IN'):
        preposition.append(word)
        
for i in range(1):
    a = r.choice(adjectives)
    n = r.choice(nouns)
    c = r.choice(conjunction)
    p = r.choice(preposition)
    print(a, n, p)

for i in range(1):
    a = r.choice(adjectives)
    n = r.choice(nouns)
    print(a, n)
    
for i in range(1):
    p = r.choice(preposition)
    print(p)
    
for i in range(1):
    a = r.choice(adjectives)
    n = r.choice(nouns)
    print(a, n)
    
for i in range(1):
    c = r.choice(conjunction)
    print(c)
    
for i in range(1):
    a = r.choice(adjectives)
    n = r.choice(nouns)
    c = r.choice(conjunction)
    p = r.choice(preposition)
    print(a, n, p)

for i in range(1):
    a = r.choice(adjectives)
    n = r.choice(nouns)
    print(a, n)
    
for i in range(1):
    a = r.choice(adjectives)
    n = r.choice(nouns)
    c = r.choice(conjunction)
    p = r.choice(preposition)
    print(a, n, p)

for i in range(1):
    a = r.choice(adjectives)
    n = r.choice(nouns)
    print(a, n)
    
for i in range(1):
    p = r.choice(preposition)
    print(p)
    
for i in range(1):
    a = r.choice(adjectives)
    n = r.choice(nouns)
    print(a, n)
    
for i in range(1):
    c = r.choice(conjunction)
    print(c)
    
for i in range(1):
    a = r.choice(adjectives)
    n = r.choice(nouns)
    c = r.choice(conjunction)
    p = r.choice(preposition)
    print(a, n, p)

for i in range(1):
    a = r.choice(adjectives)
    n = r.choice(nouns)
    print(a, n)
    
for i in range(1):
    a = r.choice(adjectives)
    n = r.choice(nouns)
    c = r.choice(conjunction)
    p = r.choice(preposition)
    print(a, n, p)

for i in range(1):
    a = r.choice(adjectives)
    n = r.choice(nouns)
    print(a, n)
    
for i in range(1):
    p = r.choice(preposition)
    print(p)
    
for i in range(1):
    a = r.choice(adjectives)
    n = r.choice(nouns)
    print(a, n)
    
for i in range(1):
    c = r.choice(conjunction)
    print(c)
    
for i in range(1):
    a = r.choice(adjectives)
    n = r.choice(nouns)
    c = r.choice(conjunction)
    p = r.choice(preposition)
    print(a, n, p)

for i in range(1):
    a = r.choice(adjectives)
    n = r.choice(nouns)
    print(a, n)
# Out:
# broken treasure in
# desperate trainer
# after
# hickory-smoke broke
# and
# large jewel of
# canary past
# radical process behind
# safe wall
# in
# old mane
# and
# secreted policy from
# British wife
# objet preacher on
# hickory-smoke truth
# of
# dire husband
# but
# English body at
# hickory-smoke packet
